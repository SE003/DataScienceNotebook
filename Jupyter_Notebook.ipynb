# %% [markdown]
# <center>
#     <img src="https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBMDeveloperSkillsNetwork-DS0105EN-SkillsNetwork/labs/Module2/images/SN_web_lightmode.png" width="300" alt="cognitiveclass.ai logo">
# </center>

# %% [markdown]
# #### Add your code below following the instructions given in the course

# %% [markdown]
# # Data Science Notebook

# %% [markdown]
# ## Introduction
#
# In this notebook, we will explore fundamental concepts related to Data Science.
# The goal is to understand essential tools, languages, and techniques that data scientists use to analyze data, build models, and gain insights.
# This introduction will help set the context for the exercises and examples that follow.

# %% [markdown]
# ## Data Science Languages
#
# - Python
# - R
# - SQL
# - Julia
# - Scala
# - Java
# - MATLAB

# %% [markdown]
# ## Data Science Libraries
#
# - NumPy
# - Pandas
# - SciPy
# - Matplotlib
# - Seaborn
# - Plotly
# - Scikit-Learn
# - TensorFlow
# - Keras
# - PyTorch
# - NLTK
# - spaCy
# - OpenCV
# - Dask
# - Polars
# - MLflow

# %% [markdown]
# ## Table of Data Science Tools
#
# | Category | Tools |
# |---------|-------|
# | Programming Languages | Python, R, SQL, Julia |
# | Data Manipulation | Pandas, NumPy, Dask, Polars |
# | Visualization | Matplotlib, Seaborn, Plotly, Bokeh, Altair |
# | Machine Learning | Scikit-Learn, XGBoost, LightGBM, CatBoost |
# | Deep Learning | TensorFlow, PyTorch, Keras, JAX |
# | NLP | NLTK, spaCy, Transformers, Gensim |
# | Computer Vision | OpenCV, Scikit-Image, Pillow |
# | Big Data | Apache Spark, Hadoop, Hive |
# | Data Engineering | Airflow, Prefect, Luigi |
# | Deployment Tools | FastAPI, Flask, MLflow, Docker |

# %% [markdown]
# ## Introduction to Arithmetic Expressions
#
# In this notebook, we will explore simple **arithmetic expressions** in Python.
# Arithmetic expressions allow us to perform basic mathematical operations such as:
#
# - **Addition** (`+`)
# - **Subtraction** (`-`)
# - **Multiplication** (`*`)
# - **Division** (`/`)
# - **Exponentiation** (`**`)
# - **Modulus** (`%`)
#
# These operations help us compute values and perform calculations within Python.

# %%
# Multiplication
a = 5
b = 10
product = a * b
print("Product:", product)

# Addition
x = 7
y = 3
sum_result = x + y
print("Sum:", sum_result)
# Out:
# Product: 50
# Sum: 10

# %%
# Convert minutes to hours

minutes = 150  # Example: 150 minutes
hours = minutes / 60

print(f"{minutes} minutes is equal to {hours} hours")
# Out:
# 150 minutes is equal to 2.5 hours

# %% [markdown]
# ## Objectives
#
# - Understand the basic concepts of Data Science
# - Learn about important Data Science libraries and tools
# - Perform arithmetic operations using Python
# - Convert units and perform basic calculations
# - Develop familiarity with Python programming in Jupyter Notebook
# - Explore data manipulation and visualization techniques

# %% [markdown]
# ## Author
#
# **Name:** Amna
